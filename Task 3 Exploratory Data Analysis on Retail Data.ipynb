# %% [markdown]
# # GRIP : The Sparks Foundation

# %% [markdown]
# ## Data Science and Business Analytics Intern

# %% [markdown]
# ### Author : Savan Kalathiya

# %% [markdown]
# #### Task 3 : Exploratory Data Analysis on Samplesuperstore Dataset

# %%
# Importing all required libraries

import pandas as pd
import numpy as np
import seaborn as sns
import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Reading the data from provided data set

df = pd.read_csv("D:\PC Info\Download\SampleSuperstore.csv")

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
## checking if there ia any missing value in the data set or not

df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#Checking the duplicate value in the data

df.duplicated().sum()
# Out:
# 17

# %%
df.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
## deleting the unnecessary features

df.drop("Postal Code", axis =1, inplace = True)

# %%
df.shape
# Out:
# (9994, 12)

# %%
## finding correlation between the variables

df.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %%
## finding covariance between the variables

df.cov()
# Out:
#                   Sales    Quantity   Discount        Profit
# Sales     388434.455308  278.459923  -3.627228  69944.096586
# Quantity     278.459923    4.951113   0.003961     34.534769
# Discount      -3.627228    0.003961   0.042622    -10.615173
# Profit     69944.096586   34.534769 -10.615173  54877.798055

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Data Visualization

# %%
plt.figure(figsize=(10,5))
plt.bar('Sub-Category','Category', data=df)
plt.title('Category vs Sub Category')
plt.xlabel('Sub-Catgory')
plt.ylabel('Category')
plt.xticks(rotation=90)
plt.show()

# %%
df.hist(bins = 50, figsize=(20,15))
plt.show()

# %%
sns.pairplot(df,hue = 'Sub-Category')

# %%
## differntiate the Numerical and Categorical features

num_cols = ['Sales', 'Profit', 'Quantity', 'Discount']
cat_cols = ['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Region', 'Category', 'Sub-Category']

# %%
len(set(num_cols))+len(set(cat_cols))
# Out:
# 12

# %%
df.select_dtypes(include = 'number')
# Out:
#          Sales  Quantity  Discount    Profit
# 0     261.9600         2      0.00   41.9136
# 1     731.9400         3      0.00  219.5820
# 2      14.6200         2      0.00    6.8714
# 3     957.5775         5      0.45 -383.0310
# 4      22.3680         2      0.20    2.5164
# ...        ...       ...       ...       ...
# 9989   25.2480         3      0.20    4.1028
# 9990   91.9600         2      0.00   15.6332
# 9991  258.5760         2      0.20   19.3932
# 9992   29.6000         4      0.00   13.3200
# 9993  243.1600         2      0.00   72.9480
#
# [9994 rows x 4 columns]

# %%
df.select_dtypes(exclude = 'number')
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#      Region         Category Sub-Category
# ...

# %% [markdown]
# ### Univariate Analysis

# %%
for i in num_cols:
    plt.figure(figsize=(6,3))
    plt.style.use("tableau-colorblind10")
    sns.distplot(df[i], bins = 50, color = 'green')
    plt.xlabel(i)
    plt.title("Frequency Distribution of" +i)
    plt.xticks(rotation = 90)
    plt.show()

# %% [markdown]
# #### Distplot represent the univariate distribution of data:
# ###### * Data distribution of a variable against density distribution

# %%
### let's use countplot for categorical feature

for i in cat_cols:
    plt.figure(figsize=(8,5))
    sns.countplot(df[i])
    plt.xlabel(i)
    plt.title("Count Distribution of" +i)
    plt.xticks(rotation = 90)
    plt.show()

# %% [markdown]
# ### Using Boxplot for detecting outliers

# %%
# cheking outliers in Sales feature

sns.boxplot(y = 'Sales', data = df)
# Out:
# <AxesSubplot:ylabel='Sales'>

# %%
# Removing outilier in Sales Features


q1 = df['Sales'].quantile(0.25)
q3 = df['Sales'].quantile(0.75)
iqr = q3-q1

#low_limit = q1-1.5*iqr
upper_limit = q3+1.5*iqr
upper_limit
# Out:
# 498.93

# %%
df['Sales']=np.where(df['Sales'] > upper_limit,upper_limit,df['Sales'])

# %%
sns.boxplot(y = 'Quantity' , data = df)
# Out:
# <AxesSubplot:ylabel='Quantity'>

# %%
# Removing outilier in Quantity Features

q1 = df['Quantity'].quantile(0.25)
q3 = df['Quantity'].quantile(0.75)
iqr = q3-q1

#low_limit = q1-1.5*iqr
upper_limit = q3+1.5*iqr
upper_limit
# Out:
# 9.5

# %%
df['Quantity']=np.where(df['Quantity'] > upper_limit,upper_limit,df['Quantity'])

# %%
# checking outliers in Discount features

sns.boxplot(y = 'Discount' , data = df)
# Out:
# <AxesSubplot:ylabel='Discount'>

# %%
# Removing outliers in Discount features

q1 = df['Discount'].quantile(0.25)
q3 = df['Discount'].quantile(0.75)
iqr = q3-q1
#low_limit = q1-1.5*iqr
upper_limit = q3+1.5*iqr
upper_limit
# Out:
# 0.5

# %%
df['Discount']=np.where(df['Discount'] > upper_limit,upper_limit,df['Discount'])

# %%
# checking outliers in Profit features

sns.boxplot(y = 'Profit' , data = df)
# Out:
# <AxesSubplot:ylabel='Profit'>

# %%
# Removing outliers in Profit features

q1 = df['Profit'].quantile(0.25)
q3 = df['Profit'].quantile(0.75)
iqr = q3-q1
lower_limit = q1-1.5*iqr
upper_limit = q3+1.5*iqr
upper_limit
# Out:
# 70.816875

# %%
df['Profit']=np.where(df['Profit'] > upper_limit,upper_limit,df['Profit'])
df['Profit']=np.where(df['Profit'] < lower_limit,lower_limit,df['Profit'])

# %%
sns.boxplot(data = df)
# Out:
# <AxesSubplot:>

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (72, 12)

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (9922, 12)

# %% [markdown]
# # Visualization And The Analysis of The Data

# %%
df.sort_values('Profit',ascending = False)
# Out:
#            Ship Mode      Segment        Country          City         State  \
# 9993    Second Class     Consumer  United States   Westminster    California
# 4270  Standard Class    Corporate  United States       Jackson     Tennessee
# 5053    Second Class     Consumer  United States        Dallas         Texas
# 5059    Second Class     Consumer  United States    Georgetown      Kentucky
# 5062  Standard Class     Consumer  United States   Minneapolis     Minnesota
# ...              ...          ...            ...           ...           ...
# 5414  Standard Class     Consumer  United States       Chicago      Illinois
# 8118  Standard Class     Consumer  United States       Chicago      Illinois
# 5420    Second Class     Consumer  United States  Philadelphia  Pennsylvania
# 3185     First Class    Corporate  United States       Houston         Texas
# 7188  Standard Class  Home Office  United States       Houston         Texas
#
# ...

# %% [markdown]
# ### From above table we can conclude that the company making profit in :
# ##### California, Indiana, Minnesota and North Carolina.
# ### From above table we can conclude that the company loosing money in :
# ##### Pennsylvania, Delaware and Arizona.

# %%
df.groupby('Region').sum( ['Profit']).sort_values("Profit")
# Out:
#                Sales  Quantity  Discount        Profit
# Region
# Central  310651.3734    8697.0    452.24  23353.578500
# South    228363.2555    6139.5    212.15  29797.785075
# East     390110.9620   10399.5    373.30  42880.462550
# West     459265.8315   12031.0    329.05  63132.158425

# %%
sns.barplot(x='Region',y='Profit',data=df)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Profit'>

# %% [markdown]
# ### Here the company makes less profit in central region and makes more profit in south and west region.

# %%
df.groupby('Category').sum( ['Profit']).sort_values("Profit")
# Out:
#                        Sales  Quantity  Discount        Profit
# Category
# Furniture        475954.3694    7887.5    350.54  24075.952525
# Technology       421620.8010    6812.5    238.20  54033.098575
# Office Supplies  490816.2520   22567.0    778.00  81054.933450

# %%
sns.barplot(x='Category',y='Profit',data=df)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Profit'>

# %% [markdown]
# ### Here the company makes more profit from the category technology, office supplies and less profit from furniture.

# %%
df.groupby(['Region','Category']).sum( ['Profit']).sort_values("Profit")
# Out:
#                                Sales  Quantity  Discount        Profit
# Region  Category
# Central Furniture        108361.0434    1807.0    128.94  -1031.821550
# East    Furniture        129987.7380    2157.5     91.70   6166.911975
# South   Furniture         74046.9505    1272.0     40.35   6970.043625
#         Technology        68180.1750    1100.0     31.60   9575.687625
# Central Office Supplies  108414.6730    5353.0    267.40  11529.141650
# West    Furniture        163558.6375    2651.0     89.55  11970.818475
# East    Technology       118483.9270    1876.0     72.30  12597.633725
# Central Technology        93875.6570    1537.0     55.90  12856.258400
# South   Office Supplies   86136.1300    3767.5    140.20  13252.053825
# West    Technology       141081.0420    2299.5     78.40  19003.518825
# East    Office Supplies  141639.2970    6366.0    209.30  24115.916850
# West    Office Supplies  154626.1520    7080.5    161.10  32157.821125

# %% [markdown]
# ### Here the company getting loss from central region and from the furniture category.

# %%
df.groupby('Segment').sum( ['Profit']).sort_values("Profit")
# Out:
#                    Sales  Quantity  Discount        Profit
# Segment
# Home Office  249322.4298    6633.5    230.33  30552.831875
# Corporate    427932.3798   11446.5    419.25  48958.125975
# Consumer     711136.6128   19187.0    717.16  79653.026700

# %%
data = df.groupby("Segment")["Profit"].sum()
data
# Out:
# Segment
# Consumer       79653.026700
# Corporate      48958.125975
# Home Office    30552.831875
# Name: Profit, dtype: float64

# %%
data.plot.pie(autopct="%.1f%%")
# Out:
# <AxesSubplot:ylabel='Profit'>

# %% [markdown]
# ### Here the company make profit from the consumers and less profit from the home office

# %%
plt.figure(figsize=(15,12))
sns.countplot(x='State',data=df,palette='Set1',order=df['State'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Conclusion :
# #### 1)From The above result we can say that the company needs to do more analysis why they loosing in the following states:                         Pennsylvania , Delaware , Arizona.
# #### 2)The company needs to enhance its marketing strategy towards Central region and also Consumers segment.
# #### 3)The Technology and Office supplies are more profitable category and needs to work on furniture category.
# ### Thank You...!
